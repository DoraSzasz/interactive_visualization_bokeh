# %% [markdown]
# > Created by Teodora Szasz, tszasz@uchicago.edu

# %% [markdown]
# # <h1 align="center">2. Visualize reported incidents of crime in Chicago (1) </h1>

# %%
# import libraries
import pandas as pd

# %%
# import Bokeh libraries - 2nd phase

from bokeh.plotting import figure
from bokeh.io import output_file, show

# %%
# create output file - 2nd phase

output_file('all_crimes.html')

# %%
# locate the file
file = '../Dataset/Crimes_-_2016_to_present.csv'

# %%
# use pandas' read_csv() method
crimes = pd.read_csv(file)

# %%
# option to be able to see all the columns
pd.set_option('display.max_columns', None)

# %% [markdown]
# - `head()` method displays the first few lines (here, three) of the table

# %%
crimes.head(5)
# Out:
#          ID Case Number                    Date                 Block  IUCR  \
# 0  10842630    JA122203  01/19/2017 06:28:15 PM   059XX S ROCKWELL ST  2022
# 1  10842633    JA122240  01/19/2017 03:18:38 PM  006XX N ST LOUIS AVE  2024
# 2  10842652    JA122480  01/20/2017 12:52:00 AM      025XX E 106TH ST  2024
# 3  10885990    JA185288  03/13/2017 08:00:00 AM   033XX W FILLMORE ST  1812
# 4  10886000    JA185322  03/13/2017 08:00:00 AM   033XX W FILLMORE ST  2024
#
#   Primary Type                     Description  \
# 0    NARCOTICS                   POSS: COCAINE
# 1    NARCOTICS             POSS: HEROIN(WHITE)
# 2    NARCOTICS             POSS: HEROIN(WHITE)
# 3    NARCOTICS  POSS: CANNABIS MORE THAN 30GMS
# 4    NARCOTICS             POSS: HEROIN(WHITE)
#
#               Location Description  Arrest  Domestic  Beat  District  Ward  \
# 0                        APARTMENT    True     False   824         8  16.0
# 1                        APARTMENT    True     False  1121        11  27.0
# 2                        RESIDENCE    True     False   434         4  10.0
# 3  POLICE FACILITY/VEH PARKING LOT    True     False  1134        11  24.0
# 4  POLICE FACILITY/VEH PARKING LOT    True     False  1134        11  24.0
#
#    Community Area FBI Code  X Coordinate  Y Coordinate  Year  \
# 0              66       18           NaN           NaN  2017
# 1              23       18           NaN           NaN  2017
# 2              51       18           NaN           NaN  2017
# 3              29       18           NaN           NaN  2017
# 4              29       18           NaN           NaN  2017
#
#                Updated On  Latitude  Longitude Location
# 0  08/05/2017 03:50:08 PM       NaN        NaN      NaN
# 1  08/05/2017 03:50:08 PM       NaN        NaN      NaN
# 2  08/05/2017 03:50:08 PM       NaN        NaN      NaN
# 3  08/05/2017 03:50:08 PM       NaN        NaN      NaN
# 4  08/05/2017 03:50:08 PM       NaN        NaN      NaN

# %%
# extract the District column - 2nd phase

crimes_district = crimes[['District']]

# %%
# count the frequency of crimes per District - 2nd phase

crimes_district['Frequency'] = crimes_district.groupby('District')['District'].transform('count')
# Out:
# /Users/rcc/anaconda3/envs/django_env/lib/python3.6/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %%
# show the first 10 rows of the crimes_district - 2nd phase

crimes_district.head(10)
# Out:
#    District  Frequency
# 0         8      16687
# 1        11      17937
# 2         4      14588
# 3        11      17937
# 4        11      17937
# 5        11      17937
# 6        11      17937
# 7        11      17937
# 8        11      17937
# 9        20       4408

# %%
# remove duplicates - 2nd phase

crimes_district_unique = crimes_district.drop_duplicates('District')

# %%
# remove duplicates - 2nd phase

crimes_district_unique
# Out:
#        District  Frequency
# 0             8      16687
# 1            11      17937
# 2             4      14588
# 9            20       4408
# 10           24       7863
# 11           25      14217
# 13           16       8942
# 14            7      13627
# 16            2      11346
# 17            5      11800
# 24           15      10374
# 25           14      10319
# 26            3      12349
# 29           18      14253
# 30           19      12031
# 32           10      12404
# 46            1      14650
# 48            9      11766
# 55           12      13599
# 56            6      16492
# 76           22       8361
# 146          17       7738
# 72017        31          3

# %%
plot = figure(plot_width=800, plot_height=800, x_axis_label='District', y_axis_label='Number of Arrests')

# %% [markdown]
# https://bokeh.pydata.org/en/latest/docs/reference/models/glyphs.html

# %%
# plot the the frequency on the crimes in each District using versical bars - 2nd phase

plot.vbar(x=list(crimes_district_unique['District']), width=0.5, bottom=0, 
          top=list(crimes_district_unique['Frequency']), color="firebrick")
# Out:
# GlyphRenderer(id='04a3e0ef-f940-44c8-81f9-78c8cee80dbe', ...)

# %%
#plot.circle(x='District', y='Frequency', source=crimes_district_unique, size=10) - 1st phase

# %%
show(plot)

# %%
from bokeh.io import output_notebook
output_notebook()
show(plot)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="9facc69d-9589-4de5-9dde-fbb011177956">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="6a6b83bb-f0b6-4aed-92b5-baff7fc6cf87"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("6a6b83bb-f0b6-4aed-92b5-baff7fc6cf87");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("6a6b83bb-f0b6-4aed-92b5-baff7fc6cf87");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '6a6b83bb-f0b6-4aed-92b5-baff7fc6cf87' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"dc16ee3a-53a4-4be4-9438-cd97e92acc8e":{"roots":{"references":[{"attributes":{},"id":"f3f9e97f-ccbc-4e55-af03-180a98ff6b2d","type":"BasicTicker"},{"attributes":{"axis_label":"District","formatter":{"id":"9c295847-2172-4f96-8ead-724826f3f637","type":"BasicTickFormatter"},"plot":{"id":"b882302b-5b49-4038-b32d-7ffcf01abd45","subtype":"Figure","type":"Plot"},"ticker":{"id":"163b7308-7818-4271-a0ee-a992ca9588db","type":"BasicTicker"}},"id":"1c0f0722-26b1-4012-95b3-637a10e9aa66","type":"LinearAxis"},{"attributes":{"data_source":{"id":"01042fdb-938e-4476-9a3f-5aafc116f963","type":"ColumnDataSource"},"glyph":{"id":"389f97f0-8fcd-4740-9f97-26891a63fc5a","type":"VBar"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"fda66943-f315-43c6-be1f-dec40a4f433f","type":"VBar"},"selection_glyph":null},"id":"04a3e0ef-f940-44c8-81f9-78c8cee80dbe","type":"GlyphRenderer"},{"attributes":{"axis_label":"Number of Arrests","formatter":{"id":"2f1143e3-481e-4a7d-91fd-59873c64f006","type":"BasicTickFormatter"},"plot":{"id":"b882302b-5b49-4038-b32d-7ffcf01abd45","subtype":"Figure","type":"Plot"},"ticker":{"id":"f3f9e97f-ccbc-4e55-af03-180a98ff6b2d","type":"BasicTicker"}},"id":"be5ff402-c24f-4e0b-90d7-65919f5146c9","type":"LinearAxis"},{"attributes":{"dimension":1,"plot":{"id":"b882302b-5b49-4038-b32d-7ffcf01abd45","subtype":"Figure","type":"Plot"},"ticker":{"id":"f3f9e97f-ccbc-4e55-af03-180a98ff6b2d","type":"BasicTicker"}},"id":"f605e3e5-f6aa-4838-82ac-e2336c327c53","type":"Grid"},{"attributes":{"fill_color":{"value":"firebrick"},"line_color":{"value":"firebrick"},"top":{"field":"top"},"width":{"value":0.5},"x":{"field":"x"}},"id":"389f97f0-8fcd-4740-9f97-26891a63fc5a","type":"VBar"},{"attributes":{},"id":"2f1143e3-481e-4a7d-91fd-59873c64f006","type":"BasicTickFormatter"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"top":{"field":"top"},"width":{"value":0.5},"x":{"field":"x"}},"id":"fda66943-f315-43c6-be1f-dec40a4f433f","type":"VBar"},{"attributes":{"plot":null,"text":""},"id":"60d8f5ec-b30a-4a9a-b17f-2f03bb9fddf8","type":"Title"},{"attributes":{"below":[{"id":"1c0f0722-26b1-4012-95b3-637a10e9aa66","type":"LinearAxis"}],"left":[{"id":"be5ff402-c24f-4e0b-90d7-65919f5146c9","type":"LinearAxis"}],"plot_height":800,"plot_width":800,"renderers":[{"id":"1c0f0722-26b1-4012-95b3-637a10e9aa66","type":"LinearAxis"},{"id":"dad9dac3-e5fa-4a7b-b5c4-aacf9d90a85a","type":"Grid"},{"id":"be5ff402-c24f-4e0b-90d7-65919f5146c9","type":"LinearAxis"},{"id":"f605e3e5-f6aa-4838-82ac-e2336c327c53","type":"Grid"},{"id":"afa75fca-7ad1-4e9e-a8dc-5788b115bcfc","type":"BoxAnnotation"},{"id":"04a3e0ef-f940-44c8-81f9-78c8cee80dbe","type":"GlyphRenderer"}],"title":{"id":"60d8f5ec-b30a-4a9a-b17f-2f03bb9fddf8","type":"Title"},"tool_events":{"id":"17fc608e-912a-4591-a631-d0e3658b8966","type":"ToolEvents"},"toolbar":{"id":"d42e699d-fae8-4fd7-8017-a9e8d82ca83a","type":"Toolbar"},"x_range":{"id":"7dc03d25-187a-4f4a-843f-2e5b8584b5ab","type":"DataRange1d"},"x_scale":{"id":"0ad7cfc3-b09a-47bc-be09-916a9f102d8d","type":"LinearScale"},"y_range":{"id":"873f35b7-c3bb-4a29-a880-42c2ff53fa3a","type":"DataRange1d"},"y_scale":{"id":"caacba9a-ea23-482b-9558-21d842a6b1f6","type":"LinearScale"}},"id":"b882302b-5b49-4038-b32d-7ffcf01abd45","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"b882302b-5b49-4038-b32d-7ffcf01abd45","subtype":"Figure","type":"Plot"}},"id":"979adda9-e089-429a-b0da-118de871e1fc","type":"PanTool"},{"attributes":{"callback":null},"id":"873f35b7-c3bb-4a29-a880-42c2ff53fa3a","type":"DataRange1d"},{"attributes":{"plot":{"id":"b882302b-5b49-4038-b32d-7ffcf01abd45","subtype":"Figure","type":"Plot"}},"id":"ac28a1b8-f6a3-4e6d-a3bb-2ec7b69930b5","type":"WheelZoomTool"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"979adda9-e089-429a-b0da-118de871e1fc","type":"PanTool"},{"id": ...
